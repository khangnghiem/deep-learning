# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/repos/deep-learning/experiments/013_pns_plus_vps
# Out:
# 013_pns_plus_vps_pipeline.ipynb  prepare_data.py
# 013_pns_plus_vps_train.ipynb	 prepare_pseudo_video.py
# checkpoints			 __pycache__
# config.yaml			 README.md
# ingest_cvc_ninja.py		 requirements.txt
# model.pt			 template_reference_train.ipynb
# prepare_data.ipynb		 train.py

# %%
import sys; sys.path.insert(0, '/content/drive/MyDrive/repos')

# %%
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/013_pns_plus_vps
# !pip install -q mlflow pyyaml Pillow
# !pip install -q tensorboardX tqdm
# Out:
# /content/drive/MyDrive/repos/deep-learning/experiments/013_pns_plus_vps
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 79.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.2/131.2 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.5/838.5 kB 66.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 23.4 MB/s eta 0:00:00
# ...

# %%
# %run train.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /content/drive/MyDrive/repos/deep-learning/experiments/013_pns_plus_vps/train.py in <module>
#      12 import albumentations as A
#      13 from albumentations.pytorch import ToTensorV2
# ---> 14 import segmentation_models_pytorch as smp
#      15
#      16 # Adjust path to find src
#
# ModuleNotFoundError: No module named 'segmentation_models_pytorch'
