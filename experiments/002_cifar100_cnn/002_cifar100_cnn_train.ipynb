# %%
# --- ENVIRONMENT SETUP: Environment-Aware Paths ---
import sys, os
from pathlib import Path

try:
    # Standard Colab setup
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    REPO_ROOT = Path(str(REPO_ROOT))
except ImportError:
    # Local fallback (assumes running from explorations/ or experiments/)
    cur = Path().resolve()
    REPO_ROOT = cur.parent if cur.name in ('explorations', 'experiments') else cur.parents[1]

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from src.config.paths import GOLD, BRONZE, SILVER, DATA_LAKE, MODELS, PRETRAINED, TRAINED, OPS, MLFLOW_TRACKING_URI, REPOS

# %% [markdown]
# # 002_cifar100_cnn
#
# **Fire-and-forget** — Run All → Close Tab → check `batch_status.ipynb` later

# %%
from google.colab import drive
drive.mount('/content/drive')
# %pip install -q --ignore-installed blinker
# %pip install -q torch torchvision torchaudio mlflow pyyaml tqdm albumentations opencv-python-headless Pillow scikit-learn
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for shared_config (pyproject.toml) ... done

# %%
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/002_cifar100_cnn
# %run train.py
# Out:
# /content/drive/MyDrive/repos/deep-learning/experiments/002_cifar100_cnn
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for shared_config (pyproject.toml) ... done
# ============================================================
# Experiment: 002_cifar100_cnn (LOCAL)
# Description: CIFAR-100 classification with CNN (100 classes)
# ============================================================
# /usr/local/lib/python3.12/dist-packages/mlflow/tracking/_tracking_service/utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# Using device: cpu
# Created SimpleCNN with 100 classes
# Trainable parameters: 346,628
# Loading CIFAR-100 from /content/drive/MyDrive/data_lake/01_bronze/cifar100
# 100%|██████████| 169M/169M [00:07<00:00, 23.1MB/s]
# Train: 50000 images, 782 batches
# Val: 10000 images, 157 batches
# Classes: 100 (fine-grained categories)
#
# Epoch 1/30
# Training:   0%|          | 0/782 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Training: 100%|██████████| 782/782 [00:29<00:00, 26.21it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 79.99it/s]
# Train - Loss: 4.0189, Acc: 0.0718
# Val   - Loss: 3.7081, Acc: 0.1186
# ✓ New best model saved! (acc: 0.1186)
#
# Epoch 2/30
# Training: 100%|██████████| 782/782 [00:29<00:00, 26.35it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 113.42it/s]
# Train - Loss: 3.5152, Acc: 0.1406
# Val   - Loss: 3.2599, Acc: 0.1774
# ✓ New best model saved! (acc: 0.1774)
#
# Epoch 3/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.66it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 111.49it/s]
# Train - Loss: 3.2111, Acc: 0.1924
# Val   - Loss: 2.9765, Acc: 0.2371
# ✓ New best model saved! (acc: 0.2371)
#
# Epoch 4/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.70it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 94.04it/s]
# Train - Loss: 2.9947, Acc: 0.2376
# Val   - Loss: 2.7060, Acc: 0.2882
# ✓ New best model saved! (acc: 0.2882)
#
# Epoch 5/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.42it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 103.21it/s]
# Train - Loss: 2.8426, Acc: 0.2661
# Val   - Loss: 2.5746, Acc: 0.3152
# ✓ New best model saved! (acc: 0.3152)
#
# Epoch 6/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.19it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 103.60it/s]
# Train - Loss: 2.7195, Acc: 0.2925
# Val   - Loss: 2.5249, Acc: 0.3325
# ✓ New best model saved! (acc: 0.3325)
#
# Epoch 7/30
# Training: 100%|██████████| 782/782 [00:29<00:00, 26.58it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 107.41it/s]
# Train - Loss: 2.6128, Acc: 0.3154
# Val   - Loss: 2.3577, Acc: 0.3713
# ✓ New best model saved! (acc: 0.3713)
#
# Epoch 8/30
# Training: 100%|██████████| 782/782 [00:29<00:00, 26.19it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 101.83it/s]
# Train - Loss: 2.5276, Acc: 0.3317
# Val   - Loss: 2.3500, Acc: 0.3783
# ✓ New best model saved! (acc: 0.3783)
#
# Epoch 9/30
# Training: 100%|██████████| 782/782 [00:30<00:00, 26.04it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 91.39it/s]
# Train - Loss: 2.4546, Acc: 0.3471
# Val   - Loss: 2.2036, Acc: 0.3978
# ✓ New best model saved! (acc: 0.3978)
#
# Epoch 10/30
# Training: 100%|██████████| 782/782 [00:29<00:00, 26.60it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 84.49it/s]
# Train - Loss: 2.3858, Acc: 0.3620
# Val   - Loss: 2.0548, Acc: 0.4343
# ✓ New best model saved! (acc: 0.4343)
#
# Epoch 11/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.30it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 109.29it/s]
# Train - Loss: 2.3429, Acc: 0.3729
# Val   - Loss: 2.0252, Acc: 0.4452
# ✓ New best model saved! (acc: 0.4452)
#
# Epoch 12/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.51it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 107.15it/s]
# Train - Loss: 2.2874, Acc: 0.3855
# Val   - Loss: 1.9333, Acc: 0.4613
# ✓ New best model saved! (acc: 0.4613)
#
# Epoch 13/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.28it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 97.31it/s]
# Train - Loss: 2.2347, Acc: 0.3986
# Val   - Loss: 1.9144, Acc: 0.4701
# ✓ New best model saved! (acc: 0.4701)
#
# Epoch 14/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.92it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 100.85it/s]
# Train - Loss: 2.2011, Acc: 0.4063
# Val   - Loss: 1.9048, Acc: 0.4715
# ✓ New best model saved! (acc: 0.4715)
#
# Epoch 15/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.34it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 96.77it/s]
# Train - Loss: 2.1594, Acc: 0.4145
# Val   - Loss: 1.8766, Acc: 0.4773
# ✓ New best model saved! (acc: 0.4773)
#
# Epoch 16/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.42it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 106.33it/s]
# Train - Loss: 2.1340, Acc: 0.4228
# Val   - Loss: 1.8514, Acc: 0.4871
# ✓ New best model saved! (acc: 0.4871)
#
# Epoch 17/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.04it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 97.40it/s]
# Train - Loss: 2.0993, Acc: 0.4312
# Val   - Loss: 1.8283, Acc: 0.4896
# ✓ New best model saved! (acc: 0.4896)
#
# Epoch 18/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.63it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 94.66it/s]
# Train - Loss: 2.0692, Acc: 0.4350
# Val   - Loss: 1.7909, Acc: 0.5037
# ✓ New best model saved! (acc: 0.5037)
#
# Epoch 19/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.33it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 91.84it/s]
# Train - Loss: 2.0371, Acc: 0.4441
# Val   - Loss: 1.7603, Acc: 0.5028
#
# Epoch 20/30
# Training: 100%|██████████| 782/782 [00:29<00:00, 26.91it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 90.04it/s]
# Train - Loss: 2.0174, Acc: 0.4480
# Val   - Loss: 1.7667, Acc: 0.5095
# ✓ New best model saved! (acc: 0.5095)
#
# Epoch 21/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.22it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 98.53it/s]
# Train - Loss: 1.9991, Acc: 0.4526
# Val   - Loss: 1.7324, Acc: 0.5122
# ✓ New best model saved! (acc: 0.5122)
#
# Epoch 22/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.45it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 109.85it/s]
# Train - Loss: 1.9658, Acc: 0.4638
# Val   - Loss: 1.7231, Acc: 0.5169
# ✓ New best model saved! (acc: 0.5169)
#
# Epoch 23/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.21it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 96.68it/s]
# Train - Loss: 1.9484, Acc: 0.4665
# Val   - Loss: 1.6839, Acc: 0.5280
# ✓ New best model saved! (acc: 0.5280)
#
# Epoch 24/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.60it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 113.09it/s]
# Train - Loss: 1.9318, Acc: 0.4718
# Val   - Loss: 1.6893, Acc: 0.5302
# ✓ New best model saved! (acc: 0.5302)
#
# Epoch 25/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.06it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 90.33it/s]
# Train - Loss: 1.9191, Acc: 0.4699
# Val   - Loss: 1.6919, Acc: 0.5267
#
# Epoch 26/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.72it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 93.35it/s]
# Train - Loss: 1.8910, Acc: 0.4786
# Val   - Loss: 1.6663, Acc: 0.5328
# ✓ New best model saved! (acc: 0.5328)
#
# Epoch 27/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.70it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 90.19it/s]
# Train - Loss: 1.8735, Acc: 0.4830
# Val   - Loss: 1.6780, Acc: 0.5260
#
# Epoch 28/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.10it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 97.76it/s]
# Train - Loss: 1.8665, Acc: 0.4842
# Val   - Loss: 1.6228, Acc: 0.5388
# ✓ New best model saved! (acc: 0.5388)
#
# Epoch 29/30
# Training: 100%|██████████| 782/782 [00:28<00:00, 27.64it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 103.77it/s]
# Train - Loss: 1.8339, Acc: 0.4918
# Val   - Loss: 1.6816, Acc: 0.5300
#
# Epoch 30/30
# Training: 100%|██████████| 782/782 [00:27<00:00, 28.56it/s]
# Validating: 100%|██████████| 157/157 [00:01<00:00, 107.60it/s]
# Train - Loss: 1.8315, Acc: 0.4920
# Val   - Loss: 1.6270, Acc: 0.5442
# ✓ New best model saved! (acc: 0.5442)
#
# ✅ Training complete! Best accuracy: 0.5442

# %%
import json
from pathlib import Path

marker = Path('completed.json')
if marker.exists():
    data = json.loads(marker.read_text())
    status = '✅' if data['success'] else '❌'
    print(f"{status} {data['experiment']}")
    print(f"   Best acc: {data['best_val_acc']}")
    print(f"   Duration: {data['duration_seconds']/60:.1f}m")
    print(f"   Model:    {data['model']}")
else:
    print('⚠️ No completion marker found')
# Out:
# ⚠️ No completion marker found

# %%
import mlflow
import torch
client = mlflow.tracking.MlflowClient()

# Find the best run dynamically
experiment = client.get_experiment_by_name('cifar100-cnn')
if experiment:
    best_run = client.search_runs(
        experiment_ids=[experiment.experiment_id],
        order_by=["metrics.best_val_acc DESC"],
        max_results=1
    )[0]
    print(f"Best Run ID: {best_run.info.run_id}")
    print(f"Best Val Acc: {best_run.data.metrics.get('best_val_acc', 'N/A')}")
    
    # Since we saved raw weights using `torch.save()`, we download the artifact
    # weights_path = mlflow.artifacts.download_artifacts(f"runs:/{best_run.info.run_id}/best_model.pt")
    # print(f"Model downloaded to: {weights_path}")
    
    # Now you can load it into your PyTorch model:
    # model = get_model(config).to(device, non_blocking=True)  # Re-initialize your blank network here
    # model.load_state_dict(torch.load(weights_path, map_location=device))
    # print("Weights loaded successfully!")
else:
    print('Experiment not found')
# Out:
# Best Run ID: c9dd58cc5b004b5fbd67c9cf03e72e87
# Best Val Acc: 0.5442

# %%
from google.colab import runtime
runtime.unassign()
