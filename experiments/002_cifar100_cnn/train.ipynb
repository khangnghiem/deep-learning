# %% [markdown]
# # Experiment: 002_cifar100_cnn
#
# **Google Colab Only** - CIFAR-100 classification (100 classes)

# %%
# Cell 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# !ls -la "/content/drive/MyDrive/repos/deep-learning/experiments/002_cifar100_cnn/"

# %%
# Cell 2: Install dependencies (uncomment on first run)
# !pip install -q torch torchvision mlflow pyyaml tqdm

# %%
# Cell 3: Run training
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/002_cifar100_cnn
# %run train_colab.py

# %%
# Cell 4: View MLflow results
import sys
sys.path.insert(0, '/content/drive/MyDrive/repos/deep-learning')

from config.paths import setup_mlflow
mlflow = setup_mlflow()
runs = mlflow.search_runs(experiment_names=['cifar100-cnn'], max_results=10)
runs[['run_id', 'metrics.best_val_acc', 'params.model', 'params.lr']]
