# %%
from google.colab import drive, runtime
drive.mount('/content/drive')
# !git clone --depth 1 -q https://github.com/khangnghiem/deep-learning.git /content/deep-learning
import os, sys
sys.path.insert(0, '/content/deep-learning')
os.chdir('/content/deep-learning/experiments/016_polyp_fast_diag')

# %%
# Check directory and install deps
# !pip install -q ultralytics
# !pip install -q opencv-python-headless
# !ls -lh /content/drive/MyDrive/data_lake/01_bronze_medical

# %%
# Run dataset preparation
# Outputs YOLO dataset directly to google drive or local
# !python prepare_dataset.py \
    --data-root /content/drive/MyDrive/data_lake/01_bronze_medical \
    --output /content/drive/MyDrive/data_lake/03_gold/016_polyp_fast_diag_dataset \
    --val-ratio 0.1 \
    --test-ratio 0.1

# %%
from google.colab import runtime
runtime.unassign()
