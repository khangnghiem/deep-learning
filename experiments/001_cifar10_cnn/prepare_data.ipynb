# %% [markdown]
# # {EXPERIMENT_NAME} — Data Preparation
#
# **Optional** — Use this notebook for interactive data preparation tasks:
# - Downloading and extracting datasets
# - Format conversion (DICOM → PNG, COCO → YOLO, etc.)
# - Visual inspection of edge cases
# - Train/val/test split creation
#
# Run this **before** `train.ipynb`. Once data is prepared, this notebook does not need to be re-run.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %pip install -q -e /content/drive/MyDrive/repos/shared_config

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/repos/deep-learning')

from shared_config.paths import BRONZE, SILVER, GOLD

# TODO: Define your dataset paths
# DATASET_NAME = 'your_dataset'
# RAW_DIR = BRONZE / DATASET_NAME
# PROCESSED_DIR = SILVER / DATASET_NAME

# %% [markdown]
# ## 1. Download / Extract Data

# %%
# TODO: Download or extract your dataset
# Example: !wget -q <url> -O /tmp/data.zip
# Example: !unzip -q /tmp/data.zip -d {RAW_DIR}

# %% [markdown]
# ## 2. Inspect & Validate

# %%
# TODO: Inspect samples, check for corruption, verify labels

# %% [markdown]
# ## 3. Process & Save

# %%
# TODO: Apply transformations and save to processed directory
# PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %%
from google.colab import runtime
runtime.unassign()
