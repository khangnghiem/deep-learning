# %% [markdown]
# # Experiment: {EXPERIMENT_NAME}
#
# **Google Colab Only** - For local, run `python train.py`

# %%
# Cell 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Verify files exist
# !ls -la "/content/drive/MyDrive/repos/deep-learning/experiments/_template/"

# %%
# Cell 2: Install dependencies (uncomment on first run)
# !pip install -q torch torchvision mlflow pyyaml tqdm

# %%
# Cell 3: Run training
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/_template
# %run train_colab.py

# %%
# Cell 4: View MLflow results (optional)
import sys
sys.path.insert(0, '/content/drive/MyDrive/repos/deep-learning')

from config.paths import setup_mlflow
mlflow = setup_mlflow()
runs = mlflow.search_runs(max_results=10)
runs[['run_id', 'metrics.best_val_acc', 'params.model']]
