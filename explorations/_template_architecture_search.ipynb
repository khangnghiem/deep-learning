# %% [markdown]
# # 🏗️ Architecture Search: {TOPIC}
#
# Quick model architecture experiments and comparisons.
#
# **Goal:** Compare different architectures/configurations before committing to a formal experiment.

# %%
# === Environment Setup ===
try:
    from google.colab import drive
    drive.mount('/content/drive')
    IN_COLAB = True
    # %pip install -q -e /content/drive/MyDrive/repos/shared_config
except ImportError:
    IN_COLAB = False

import sys
if IN_COLAB:
    sys.path.insert(0, '/content/drive/MyDrive/repos/deep-learning')
else:
    sys.path.insert(0, '..')

# %% [markdown]
# ## 1. Compare Models

# %%
# TODO: Compare model params, FLOPs, forward pass
