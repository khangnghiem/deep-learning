# %%
# !pip install -q ultralytics mlflow sahi
from google.colab import drive, runtime
import time
for _ in range(5):
    try:
        drive.mount('/content/drive', force_remount=True)
        break
    except Exception as e:
        print('Mount failed', e)
        time.sleep(5)

# %%
# !git clone --depth 1 -q https://github.com/khangnghiem/deep-learning.git /content/deep-learning
import os, sys
sys.path.insert(0, '/content/deep-learning')
os.chdir('/content/deep-learning/experiments/023_polyp_sahi')

# %%
# %run infer.py

# %%
runtime.unassign()
