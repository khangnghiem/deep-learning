# %%
# --- ENVIRONMENT SETUP: Environment-Aware Paths ---
import sys, os
from pathlib import Path

try:
    # Standard Colab setup
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    REPO_ROOT = Path(str(REPO_ROOT))
except ImportError:
    # Local fallback (assumes running from explorations/ or experiments/)
    cur = Path().resolve()
    REPO_ROOT = cur.parent if cur.name in ('explorations', 'experiments') else cur.parents[1]

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from src.config.paths import GOLD, BRONZE, SILVER, DATA_LAKE, MODELS, PRETRAINED, TRAINED, OPS, MLFLOW_TRACKING_URI, REPOS

# %% [markdown]
# # 001_cifar10_cnn
#
# **Fire-and-forget** — Run All → Close Tab → check `batch_status.ipynb` later

# %%
from google.colab import drive
drive.mount('/content/drive')
# %pip install -q --ignore-installed blinker
# %pip install -q torch torchvision mlflow pyyaml tqdm albumentations opencv-python-headless Pillow scikit-learn
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 91.9 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 101.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.4/369.4 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 22.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 85.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.2/131.2 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.4 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.5/838.5 kB 60.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.9/613.9 kB 49.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.5/583.5 kB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.3/226.3 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for shared_config (pyproject.toml) ... done

# %%
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/001_cifar10_cnn
# %run train.py
# Out:
# /content/drive/MyDrive/repos/deep-learning/experiments/001_cifar10_cnn
# ============================================================
# Experiment: 001_cifar10_cnn (LOCAL)
# ============================================================
# /usr/local/lib/python3.12/dist-packages/mlflow/tracking/_tracking_service/utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# Using device: cpu
# Created SimpleCNN with 10 classes
# Trainable parameters: 323,498
# Loading CIFAR-10 from /content/drive/MyDrive/data_lake/01_bronze/cifar10
# Train: 50000 images, 782 batches
# Val: 10000 images, 157 batches
#
# Epoch 1/20
# Training:   0%|          | 0/782 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Training: 100%|██████████| 782/782 [00:41<00:00, 19.05it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 62.80it/s]
# Train - Loss: 1.4757, Acc: 0.4506
# Val   - Loss: 1.1478, Acc: 0.5769
# ✓ New best model saved! (acc: 0.5769)
#
# Epoch 2/20
# Training: 100%|██████████| 782/782 [00:40<00:00, 19.24it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 64.20it/s]
# Train - Loss: 1.1141, Acc: 0.6027
# Val   - Loss: 1.0923, Acc: 0.6155
# ✓ New best model saved! (acc: 0.6155)
#
# Epoch 3/20
# Training: 100%|██████████| 782/782 [00:40<00:00, 19.08it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 62.39it/s]
# Train - Loss: 0.5648, Acc: 0.8073
# Val   - Loss: 0.4858, Acc: 0.8335
# ✓ New best model saved! (acc: 0.8335)
#
# Epoch 15/20
# Training: 100%|██████████| 782/782 [00:39<00:00, 19.63it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 67.66it/s]
# Train - Loss: 0.5537, Acc: 0.8110
# Val   - Loss: 0.4929, Acc: 0.8375
# ✓ New best model saved! (acc: 0.8375)
#
# Epoch 16/20
# Training: 100%|██████████| 782/782 [00:40<00:00, 19.24it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 64.21it/s]
# Train - Loss: 0.5369, Acc: 0.8172
# Val   - Loss: 0.5069, Acc: 0.8287
#
# Epoch 17/20
# Training: 100%|██████████| 782/782 [00:40<00:00, 19.18it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 63.03it/s]
# Train - Loss: 0.5265, Acc: 0.8206
# Val   - Loss: 0.4916, Acc: 0.8396
# ✓ New best model saved! (acc: 0.8396)
#
# Epoch 18/20
# Training: 100%|██████████| 782/782 [00:40<00:00, 19.27it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 64.80it/s]
# Train - Loss: 0.5182, Acc: 0.8235
# Val   - Loss: 0.5182, Acc: 0.8274
#
# Epoch 19/20
# Training: 100%|██████████| 782/782 [00:39<00:00, 19.88it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 64.02it/s]
# Train - Loss: 0.5066, Acc: 0.8282
# Val   - Loss: 0.4781, Acc: 0.8368
#
# Epoch 20/20
# Training: 100%|██████████| 782/782 [00:39<00:00, 19.89it/s]
# Validating: 100%|██████████| 157/157 [00:02<00:00, 59.77it/s]
# Train - Loss: 0.4968, Acc: 0.8332
# Val   - Loss: 0.4413, Acc: 0.8503
# ✓ New best model saved! (acc: 0.8503)
#
# Training complete! Best accuracy: 0.8503

# %%
import json
from pathlib import Path

marker = Path('completed.json')
if marker.exists():
    data = json.loads(marker.read_text())
    status = '✅' if data['success'] else '❌'
    print(f"{status} {data['experiment']}")
    print(f"   Best acc: {data['best_val_acc']}")
    print(f"   Duration: {data['duration_seconds']/60:.1f}m")
    print(f"   Model:    {data['model']}")
else:
    print('⚠️ No completion marker found')
# Out:
# ⚠️ No completion marker found

# %%
import mlflow
import torch
client = mlflow.tracking.MlflowClient()

# Find the best run dynamically
experiment = client.get_experiment_by_name('cifar10-cnn')
if experiment:
    best_run = client.search_runs(
        experiment_ids=[experiment.experiment_id],
        order_by=["metrics.best_val_acc DESC"],
        max_results=1
    )[0]
    print(f"Best Run ID: {best_run.info.run_id}")
    print(f"Best Val Acc: {best_run.data.metrics.get('best_val_acc', 'N/A')}")
    
    # Since we saved raw weights using `torch.save()`, we download the artifact rather than use `load_model`
    # weights_path = mlflow.artifacts.download_artifacts(f"runs:/{best_run.info.run_id}/best_model.pt")
    # print(f"Model downloaded to: {weights_path}")
    
    # Now you can load it into your PyTorch model:
    # model = get_model(config).to(device, non_blocking=True)  # Re-initialize your blank network here
    # model.load_state_dict(torch.load(weights_path, map_location=device))
    # print("Weights loaded successfully!")
else:
    print('Experiment not found')
# Out:
# Best Run ID: d658d848a53445d7bc5dcf653f17624a
# Best Val Acc: 0.8503

# %%
from google.colab import runtime
runtime.unassign()
