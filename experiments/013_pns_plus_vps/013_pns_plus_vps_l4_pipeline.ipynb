# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/013_pns_plus_vps
# !pip install -q mlflow pyyaml albumentations segmentation-models-pytorch

# %% [markdown]
# import os, sys
# root = "/content/drive/MyDrive/repos/deep-learning"
# # Correctly add both potential roots to sys.path
# if root not in sys.path:
#     sys.path.insert(0, root)
#     src_path = os.path.join(root, "src")
#     if src_path not in sys.path:
#         sys.path.insert(0, src_path)
#
#         os.environ['PYTHONPATH'] = f"{root}:{src_path}"
#         os.chdir(os.path.join(root, "experiments/013_pns_plus_vps"))
#
#         print(f"CWD: {os.getcwd()}")
#         print(f"Sys Path: {sys.path[:2]}")
#
#         !python train.py

# %% [markdown]
# !pip install -q mlflow pyyaml albumentations segmentation-models-pytorch
# import os, sys
# repos_root = "/content/drive/MyDrive/repos"
# # Add both sibling repos to sys.path
# sys.path.insert(0, os.path.join(repos_root, "deep-learning"))
# sys.path.insert(0, os.path.join(repos_root, "shared_config"))
# os.environ['PYTHONPATH'] = f"{os.path.join(repos_root, 'deep-learning')}:{os.path.join(repos_root, 'shared_config')}"
# os.chdir(os.path.join(repos_root, "deep-learning/experiments/013_pns_plus_vps"))
# !python train.py

# %%
# !find /content/drive/MyDrive -name "shared_config*"

# %%
from google.colab import runtime
runtime.unassign()

# %%
# !pip install -q mlflow pyyaml albumentations segmentation-models-pytorch
import os, sys
repos_root = "/content/drive/MyDrive/repos"
sys.path.insert(0, os.path.join(repos_root, "deep-learning"))
sys.path.insert(0, os.path.join(repos_root, "shared_config"))
os.environ['PYTHONPATH'] = f"{os.path.join(repos_root, 'deep-learning')}:{os.path.join(repos_root, 'shared_config')}"
os.chdir(os.path.join(repos_root, "deep-learning/experiments/013_pns_plus_vps"))
# !python train.py
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 92.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 129.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 kB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.2/131.2 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.5/838.5 kB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 25.5 MB/s eta 0:00:00
# ...
