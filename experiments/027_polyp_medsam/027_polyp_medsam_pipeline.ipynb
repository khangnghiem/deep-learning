# %%
# Cell 1: Environment Setup
# !pip install -q transformers datasets monai mlflow mlflow-skinny
from google.colab import drive, runtime
import time
for _ in range(5):
    try:
        drive.mount('/content/drive', force_remount=True)
        break
    except Exception as e:
        print('Mount failed', e)
        time.sleep(5)

# %%
# Cell 2: Clone repo
import os, sys
if os.path.exists('/content/deep-learning'):
    # !cd /content/deep-learning && git pull
else:
    # !git clone --depth 1 -q https://github.com/khangnghiem/deep-learning.git /content/deep-learning
sys.path.insert(0, '/content/deep-learning')
os.chdir('/content/deep-learning/experiments/027_polyp_medsam')

# %%
# Cell 3: Train MedSAM Domain Adaptation
# %run train.py

# %%
# Cell 4: Cleanup runtime
runtime.unassign()
