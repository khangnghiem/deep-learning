# %% [markdown]
# # Experiment: 001_cifar10_cnn
#
# **Google Colab Only** - For local, run `python train.py` instead.
#
# Steps:
# 1. Run cell 1 to mount Drive
# 2. Run cell 2 to install dependencies (first time only)
# 3. Run cell 3 to train

# %%
# Cell 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Verify files exist
# !ls -la "/content/drive/MyDrive/repos/deep-learning/experiments/001_cifar10_cnn/"

# %%
# Cell 2: Install dependencies (uncomment on first run)
# !pip install -q torch torchvision mlflow pyyaml tqdm

# %%
# Cell 3: Run training
# %cd /content/drive/MyDrive/repos/deep-learning/experiments/001_cifar10_cnn
# %run train_colab.py

# %%
# Cell 4: View MLflow results (optional)
import sys
sys.path.insert(0, '/content/drive/MyDrive/repos/deep-learning')

from config.paths import setup_mlflow
mlflow = setup_mlflow()
runs = mlflow.search_runs(experiment_names=['cifar10-cnn'], max_results=10)
runs[['run_id', 'metrics.best_val_acc', 'params.model', 'params.lr']]
